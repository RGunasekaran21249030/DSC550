# %% [markdown]
# # Week 2 : Assignment
#
# Name : Ragunath Gunasekaran

# %%
import pandas as pd
import unicodedata
import sys
import numpy as np

from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ## Reading the controversial-comments.jsonl file into a DataFrame

# %%
# the controversial comments availabe in the Data Files/controversial-comments/controversial-comments.jsonl
Con_com_df = pd.read_json('Data Files/controversial-comments/controversial-comments.jsonl',lines=True)
print (Con_com_df)
# Out:
#         con                                                txt
# 0         0  Well it's great that he did something about th...
# 1         0                       You are right Mr. President.
# 2         0  You have given no input apart from saying I am...
# 3         0  I get the frustration but the reason they want...
# 4         0  I am far from an expert on TPP and I would ten...
# ...     ...                                                ...
# 949995    0  I genuinely can't understand how anyone can su...
# 949996    0  As a reminder, this subreddit [is for civil di...
# 949997    0                  K. Don't explain why or anything.
# 949998    0                                          [deleted]
# 949999    0  Ya, sociopaths are known for celebrating their...
#
# [950000 rows x 2 columns]

# %% [markdown]
# ## Convert all text to lowercase letters

# %%
# converting into the lowercase
Con_com_df["txt"]=Con_com_df["txt"].apply(lambda x: x.lower())
Con_com_df["txt"]
# Out:
# 0         well it's great that he did something about th...
# 1                              you are right mr. president.
# 2         you have given no input apart from saying i am...
# 3         i get the frustration but the reason they want...
# 4         i am far from an expert on tpp and i would ten...
#                                 ...
# 949995    i genuinely can't understand how anyone can su...
# 949996    as a reminder, this subreddit [is for civil di...
# 949997                    k. don't explain why or anything.
# 949998                                            [deleted]
# 949999    ya, sociopaths are known for celebrating their...
# Name: txt, Length: 950000, dtype: object

# %% [markdown]
# ## Remove all punctuation from the text

# %%
punctuation = dict.fromkeys(i for i in range(sys.maxunicode) if unicodedata.category(chr(i)).startswith('P'))
# removing puncutation
Con_com_df["txt"]= [string.translate(punctuation) for string in Con_com_df["txt"]]

# %%
Con_com_df
# Out:
#         con                                                txt
# 0         0  well its great that he did something about tho...
# 1         0                         you are right mr president
# 2         0  you have given no input apart from saying i am...
# 3         0  i get the frustration but the reason they want...
# 4         0  i am far from an expert on tpp and i would ten...
# ...     ...                                                ...
# 949995    0  i genuinely cant understand how anyone can sup...
# 949996    0  as a reminder this subreddit is for civil disc...
# 949997    0                     k dont explain why or anything
# 949998    0                                            deleted
# 949999    0  ya sociopaths are known for celebrating their ...
#
# [950000 rows x 2 columns]

# %% [markdown]
# ## Remove stop words

# %%
Con_com_df["txt"] = Con_com_df["txt"].str.lower().str.split()

stop = stopwords.words('english')
# Removing stop words
Con_com_df["txt"].apply(lambda x: [item for item in x if item not in stop])

# %% [markdown]
# ## NLTK’s PorterStemmer

# %%
# PorterStemmer
ps = PorterStemmer()

# Applying NLTK’s PorterStemmer
Con_com_df["txt"] = Con_com_df["txt"].apply(lambda word_list: [ ps.stem(word) for word in word_list])

# %% [markdown]
# ##  Convert each text entry into a word-count vector

# %%
# Calling Vectorizer from NLTK
count = CountVectorizer()
# using count fit transform
bagofwords=count.fit_transform(Con_com_df["txt"])

# %%
bagofwords
# Out:
# <950000x189015 sparse matrix of type '<class 'numpy.int64'>'
# 	with 25712788 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ##  Convert each text entry into a part-of-speech tag vector

# %%
words = Con_com_df["txt"].values.flatten()
# declaring array
part_of_speechTag = []

# tag each word and each text
for word in words:
    word_tag = nltk.pos_tag(word_tokenize(word))
    part_of_speechTag.append([tag for word, tag in word_tag])

# use one hot encoding to convert the tags into features
one_hot_multi = MultiLabelBinarizer()
one_hot_multi.fit_transform(part_of_speechTag)

# %% [markdown]
# ## Convert each entry into a term frequency-inverse document frequency (tfidf) vector

# %%
tfidf = TfidfVectorizer()
# Term Frequ-inverse document vector
feature_matrix = tfidf.fit_transform(Con_com_df["txt"])
feature_matrix
# Out:
# <950000x189015 sparse matrix of type '<class 'numpy.float64'>'
# 	with 25712788 stored elements in Compressed Sparse Row format>

# %%
tfidf.vocabulary_
# Out:
# {'well': 182092,
#  'it': 102788,
#  'great': 89579,
#  'that': 166398,
#  'he': 92739,
#  'did': 68366,
#  'something': 158044,
#  'about': 33061,
#  'those': 168190,
#  'beliefs': 44300,
#  'while': 182815,
#  'was': 181174,
#  'in': 99201,
#  'office': 127833,
#  'doubt': 71522,
#  'trump': 171398,
#  'would': 185019,
#  'fight': 81645,
#  'the': 166466,
#  'un': 174443,
#  'for': 83337,
#  'so': 157521,
#  'really': 143211,
#  'happy': 92015,
#  'obama': 127029,
#  'could': 60449,
#  'oh': 127966,
#  'wait': 180715,
#  'you': 187125,
#  'are': 39035,
#  'right': 147471,
#  'mr': 121021,
#  'president': 138085,
#  'have': 92517,
#  'given': 87789,
#  'no': 125118,
#  'input': 100764,
#  'apart': 38251,
#  'from': 84647,
#  'saying': 151029,
#  'am': 36461,
#  'wrong': 185295,
#  'argument': 39122,
#  'clearly': 55764,
#  'get': 87216,
#  'frustration': 84778,
#  'but': 50202,
#  'reason': 143326,
#  'they': 167826,
#  'want': 180954,
#  'them': 167411,
#  'to': 169240,
#  'do': 70353,
#  'way': 181494,
#  'is': 102435,
#  'because': 43888,
#  'its': 102903,
#  'foundation': 83830,
#  'more': 120470,
#  'complex': 57931,
#  'problems': 138806,
#  'as': 39789,
#  'advance': 34386,
#  'grades': 89252,
#  'can': 51478,
#  'decent': 65618,
#  'grade': 89248,
#  'on': 128472,
#  'an': 37042,
#  'sat': 150780,
#  'type': 173702,
#  'test': 166113,
#  'math': 115695,
#  'don': 70782,
#  'understand': 175121,
#  'lot': 112714,
#  'of': 127762,
#  'mathematical': 115700,
#  'ways': 181513,
#  'answer': 37759,
#  'lots': 112721,
#  'times': 168841,
#  'figure': 81665,
#  'out': 129872,
#  'common': 57641,
#  'sense': 153059,
#  'work': 184785,
#  'around': 39359,
#  'questions': 141516,
#  'be': 43687,
#  'ill': 98245,
#  'prepared': 137920,
#  'take': 164584,
#  'college': 57104,
#  'level': 110409,
#  'courses': 60686,
#  'despite': 67589,
#  'above': 33073,
#  'average': 41293,
#  'score': 151847,
#  're': 142961,
#  'not': 125910,
#  'just': 105512,
#  'trying': 172734,
#  'bust': 50176,
#  'kids': 106872,
#  'balls': 42607,
#  'far': 80147,
#  'expert': 78746,
#  'tpp': 170137,
#  'and': 37224,
#  'tend': 165798,
#  'agree': 35075,
#  'had': 91168,
#  'my': 121975,
#  'understanding': 175126,
#  'pushing': 140560,
#  'create': 61227,
#  'economic': 73847,
#  'bulwark': 49743,
#  'against': 34882,
#  'china': 54495,
#  'pacific': 131039,
#  'his': 94490,
#  'administration': 34195,
#  'recognized': 143680,
#  'increasing': 99654,
#  'strength': 161548,
#  'maturity': 115813,
#  'bellicosity': 44370,
#  'see': 152615,
#  'south': 158420,
#  'sea': 152263,
#  'us': 177210,
#  'allies': 36089,
#  'push': 140551,
#  'increased': 99649,
#  'penetration': 133016,
#  'into': 101732,
#  'many': 114932,
#  'emerging': 75562,
#  'markets': 115229,
#  'otherwise': 129734,
#  'naturally': 123129,
#  'align': 35931,
#  'with': 184175,
#  'always': 36442,
#  'thought': 168206,
#  'curious': 62526,
#  'critiques': 61582,
#  'hardly': 92111,
#  'saw': 150992,
#  'mention': 117311,
#  'why': 183318,
#  'has': 92314,
#  'track': 170177,
#  'record': 143762,
#  'someone': 158019,
#  'railroad': 142201,
#  'workers': 184801,
#  'corporate': 60098,
#  'interests': 101401,
#  'there': 167604,
#  'must': 121805,
#  'been': 44013,
#  'felt': 81109,
#  'hugely': 96289,
#  'important': 99007,
#  'use': 177430,
#  'much': 121239,
#  'political': 136088,
#  'capital': 51807,
#  'like': 111127,
#  'maybe': 115933,
#  'better': 45074,
#  'certainly': 53317,
#  'seems': 152670,
#  'yet': 186821,
#  'best': 44980,
#  'manage': 114589,
#  'varied': 178316,
#  'at': 40483,
#  'play': 135309,
#  'however': 95937,
#  'does': 70510,
#  'seem': 152658,
#  'strategic': 161428,
#  'interest': 101393,
#  'if': 97907,
#  'we': 181634,
#  'only': 128602,
#  'throw': 168393,
#  'begin': 44103,
#  'significant': 155423,
#  'withdrawal': 184187,
#  'foreign': 83451,
#  'will': 183736,
#  'definitely': 66110,
#  'move': 120915,
#  'fill': 81748,
#  'void': 179759,
#  'may': 115924,
#  'very': 178815,
#  'looking': 112446,
#  'end': 75980,
#  'western': 182249,
#  'hegemony': 93108,
#  'election': 74874,
#  'ascendency': 39840,
#  'other': 129711,
#  'nationalistic': 123032,
#  'movements': 120923,
#  'britain': 48877,
#  'france': 84069,
#  'elsewhere': 75305,
#  'what': 182488,
#  'sad': 149974,
#  'appears': 38482,
#  'entirely': 76509,
#  'self': 152812,
#  'inflicted': 100261,
#  'nothing': 125989,
#  'forcing': 83394,
#  'retraction': 146715,
#  'developed': 67886,
#  'democracies': 66621,
#  'simply': 155638,
#  'result': 146546,
#  'myopic': 122055,
#  'reactions': 143010,
#  'globalism': 88076,
#  'thanks': 166366,
#  'playing': 135341,
#  'feel': 80987,
#  'her': 93420,
#  'now': 126154,
#  'https': 96166,
#  'thenypost': 167496,
#  'files': 81719,
#  'wordpress': 184771,
#  'com': 57293,
#  '2016': 6065,
#  '11': 1894,
#  '161109': 3986,
#  'clinton': 56009,
#  'camp': 51399,
#  '01': 229,
#  'jpg': 105100,
#  'quality': 141330,
#  '90': 29394,
#  'amp': 36942,
#  'strip': 161635,
#  'all': 35972,
#  '642': 25288,
#  'lol': 112267,
#  'deleted': 66359,
#  'cant': 51719,
#  'racist': 141978,
#  'black': 46161,
#  'friend': 84531,
#  'lololol': 112315,
#  'vast': 178361,
#  'majority': 114286,
#  'misogynists': 119084,
#  'history': 94545,
#  'weren': 182187,
#  'married': 115311,
#  'women': 184538,
#  'nope': 125678,
#  'both': 47838,
#  'smoke': 157022,
#  'bad': 42246,
#  'lungs': 113255,
#  'tobacco': 169276,
#  'carcinogens': 51984,
#  'plain': 135165,
#  'old': 128210,
#  'heavy': 92995,
#  'metals': 117571,
#  'mj': 119396,
#  'doesn': 70520,
#  'being': 44216,
#  'industrially': 100023,
#  'farmed': 80213,
#  'lt': 112997,
#  'exactly': 78181,
#  'means': 116528,
#  'especially': 77319,
#  'when': 182705,
#  'power': 137236,
#  'existing': 78557,
#  'rights': 147517,
#  'away': 41421,
#  'gt': 90225,
#  'politicians': 136165,
#  'one': 128514,
#  'clear': 55748,
#  'example': 78219,
#  'democrats': 66694,
#  'were': 182182,
#  'gay': 86465,
#  'marriage': 115308,
#  'before': 44063,
#  'hillary': 94062,
#  'evolved': 78098,
#  'respond': 146399,
#  'popular': 136692,
#  'opinion': 128950,
#  'society': 157666,
#  'gives': 87794,
#  'or': 129157,
#  'judges': 105273,
#  'show': 154937,
#  'me': 116465,
#  'mainstream': 114214,
#  'republican': 145917,
#  'taking': 164620,
#  'aren': 39060,
#  'expanding': 78634,
#  've': 178455,
#  'duped': 72846,
#  'by': 50505,
#  'propaganda': 139310,
#  'believe': 44309,
#  'isn': 102643,
#  'canada': 51501,
#  'uk': 174235,
#  'current': 62556,
#  'legal': 109914,
#  'mechanism': 116599,
#  'states': 160378,
#  'secede': 152427,
#  'save': 150944,
#  'successful': 162343,
#  'revolution': 146997,
#  'california': 51191,
#  'referendum': 144352,
#  'laughed': 109238,
#  'federal': 80867,
#  'court': 60690,
#  'meaningless': 116522,
#  'words': 184772,
#  'keep': 106319,
#  'fire': 82006,
#  'contained': 59270,
#  'until': 176697,
#  'anything': 38156,
#  'wants': 180964,
#  'people': 133162,
#  'stop': 161193,
#  'pretending': 138305,
#  'than': 166346,
#  'air': 35362,
#  'declare': 65719,
#  'himself': 94342,
#  'dictator': 68335,
#  'life': 110996,
#  'honestly': 95292,
#  'too': 169619,
#  'upset': 177016,
#  'classic': 55639,
#  'case': 52335,
#  'government': 89068,
#  'department': 67060,
#  'interior': 101427,
#  'giving': 87800,
#  'rats': 142757,
#  'ass': 40073,
#  'native': 123079,
#  'americans': 36730,
#  'gov': 89021,
#  'treaties': 170733,
#  'community': 57706,
#  'organizer': 129373,
#  'supported': 163054,
#  'redistribution': 144057,
#  'wealth': 181680,
#  'wanted': 180956,
#  'money': 120039,
#  'lenders': 110160,
#  'call': 51244,
#  'him': 94327,
#  'loser': 112683,
#  'crying': 61976,
#  'unattractive': 174553,
#  'good': 88630,
#  'time': 168781,
#  'invoke': 102035,
#  'this': 168019,
#  'www': 185580,
#  'reddit': 143922,
#  'politics': 136193,
#  'comments': 57541,
#  '5eqcqn': 20394,
#  'stanford_professor_develops_trump_conversion': 160140,
#  'daee57e': 63879,
#  'most': 120707,
#  'characteristics': 53782,
#  'abusers': 33263,
#  'noticed': 126016,
#  'worked': 184797,
#  'disabilities': 68947,
#  'attitude': 40761,
#  'client': 55895,
#  'resistance': 146282,
#  'abuse': 33257,
#  'itself': 102930,
#  'justification': 105567,
#  'once': 128501,
#  'feedback': 80950,
#  'loop': 112565,
#  'established': 77407,
#  'control': 59544,
#  'justified': 105569,
#  'through': 168381,
#  'acquiescence': 33735,
#  'behavior': 44146,
#  'wise': 184109,
#  'escape': 77237,
#  'same': 150342,
#  'holds': 94973,
#  'true': 171342,
#  'abusive': 33266,
#  'relationships': 145017,
#  'prisons': 138635,
#  'police': 135988,
#  'any': 38105,
#  'kind': 107008,
#  'authoritarian': 41064,
#  'regime': 144590,
#  'broader': 48948,
#  'message': 117508,
#  'your': 187205,
#  'behave': 44141,
#  'first': 82104,
#  'place': 135119,
#  'remember': 145261,
#  'over': 130203,
#  'next': 124451,
#  'four': 83863,
#  'years': 186645,
#  'hear': 92898,
#  'trope': 171222,
#  'won': 184568,
#  'appointees': 38581,
#  'boo': 47447,
#  'mike': 118206,
#  'pence': 132963,
#  'protest': 139593,
#  'streets': 161534,
#  'explain': 78765,
#  'death': 65377,
#  'threats': 168310,
#  'got': 88942,
#  'elected': 74860,
#  'course': 60681,
#  'think': 167941,
#  'some': 157986,
#  'poor': 136609,
#  'person': 133583,
#  'give': 87782,
#  'handouts': 91833,
#  'who': 183108,
#  'need': 123576,
#  'submission': 162108,
#  'automatically': 41174,
#  'removed': 145350,
#  'either': 74698,
#  'link': 111326,
#  'shortener': 154832,
#  'redirector': 144041,
#  'allow': 36147,
#  'shorterners': 154838,
#  'redirectors': 144042,
#  'users': 177476,
#  'should': 154889,
#  'able': 32965,
#  'tell': 165688,
#  'where': 182735,
#  'going': 88462,
#  'click': 55871,
#  'encouraged': 75944,
#  'resubmit': 146542,
#  'url': 177175,
#  'points': 135896,
#  'directly': 68873,
#  'content': 59320,
#  'submitting': 162120,
#  'information': 100322,
#  'found': 83825,
#  'here': 93456,
#  'wiki': 183544,
#  'filtereddomains': 81793,
#  'wiki_link_shorteners': 183555,
#  '2fredirects': 10201,
#  'bot': 47822,
#  'action': 33796,
#  'performed': 133345,
#  'please': 135391,
#  'contact': 59253,
#  'moderators': 119740,
#  'subreddit': 162160,
#  'compose': 57978,
#  'concerns': 58186,
#  'pretty': 138340,
#  'lay': 109432,
#  'man': 114566,
#  'term': 165944,
#  'supply': 163039,
#  'side': 155255,
#  'economics': 73867,
#  'discredit': 69208,
#  'personally': 133603,
#  'anybody': 38116,
#  'says': 151034,
#  'democrat': 66645,
#  'party': 131988,
#  'fucking': 84965,
#  'moron': 120570,
#  'thing': 167922,
#  'made': 113865,
#  'up': 176860,
#  'name': 122651,
#  'read': 143021,
#  'pick': 134456,
#  'already': 36297,
#  'point': 135884,
#  'doing': 70606,
#  'past': 132078,
#  'year': 186621,
#  'look': 112433,
#  'ended': 76009,
#  'falling': 79929,
#  'goddamn': 88368,
#  'funny': 85354,
#  'then': 167472,
#  'make': 114301,
#  'solipsism': 157919,
#  'fair': 79749,
#  'legalize': 109935,
#  'help': 93294,
#  'pay': 132407,
#  'crazy': 61174,
#  'spending': 158969,
#  'plans': 135223,
#  'guessing': 90410,
#  'benefit': 44504,
#  'taxes': 165144,
#  'though': 168204,
#  'crucified': 61837,
#  'liberals': 110726,
#  'university': 175931,
#  'campuses': 51465,
#  'exact': 78172,
#  'their': 167359,
#  'hardest': 92093,
#  'shut': 155145,
#  'down': 71634,
#  'conservative': 58897,
#  'speech': 158889,
#  'ideas': 97539,
#  'honest': 95289,
#  'extreme': 79084,
#  'sides': 155286,
#  'ideologues': 97581,
#  'care': 52012,
#  'team': 165353,
#  'real': 143112,
#  'issue': 102732,
#  'yeah': 186610,
#  'still': 160948,
#  'schedule': 151415,
#  'raided': 142187,
#  'dispensaries': 69600,
#  'violating': 179341,
#  'state': 160308,
#  'laws': 109399,
#  'consider': 58960,
#  'libertarian': 110768,
#  'cutting': 62721,
#  'military': 118322,
#  'dismantling': 69503,
#  'dea': 65238,
#  'big': 45417,
#  'ever': 77900,
#  'll': 111847,
#  'leave': 109723,
#  'high': 93888,
#  'dry': 72380,
#  'ask': 39948,
#  'snowden': 157454,
#  'brain': 48189,
#  'theredpill': 167633,
#  'guys': 90764,
#  'didn': 68409,
#  'fuck': 84902,
#  'anti': 37844,
#  'come': 57366,
#  'said': 150122,
#  'stuff': 161827,
#  'supposed': 163080,
#  'say': 151013,
#  'intro': 101807,
#  'phone': 134251,
#  'knowingly': 107527,
#  'harbored': 92056,
#  'bin': 45745,
#  'laden': 108573,
#  'rescind': 146140,
#  'aid': 35304,
#  'go': 88272,
#  'suck': 162385,
#  'fat': 80359,
#  'dick': 68252,
#  'ugly': 174131,
#  'also': 36318,
#  'died': 68424,
#  'conway': 59722,
#  'queen': 141446,
#  'long': 112366,
#  'game': 86040,
#  'complete': 57915,
#  'elimination': 75153,
#  'public': 140093,
#  'education': 74118,
#  'these': 167720,
#  'despise': 67584,
#  'fact': 79602,
#  'dollars': 70661,
#  'educate': 74112,
#  'lower': 112864,
#  'class': 55631,
#  'turn': 173218,
#  'compete': 57844,
#  'privileged': 138705,
#  'position': 136893,
#  'truly': 171376,
#  'incredible': 99660,
#  'mental': 117283,
#  'gymnastics': 90872,
#  'done': 71146,
#  'weird': 182021,
#  'our': 129825,
#  'stock': 161080,
#  'places': 135134,
#  'running': 149204,
#  'integrity': 101208,
#  'refuse': 144519,
#  'know': 107513,
#  'question': 141500,
#  'ahead': 35203,
#  'debate': 65435,
#  'leaked': 109636,
#  'she': 153995,
#  'possibly': 136952,
#  'reduce': 144151,
#  'everyones': 77973,
#  'cheer': 54082,
#  'settles': 153422,
#  'conservatives': 58922,
#  'hell': 93226,
#  'less': 110290,
#  'corrupt': 60242,
#  'almost': 36223,
#  'politician': 136162,
#  'zero': 187891,
#  'substance': 162233,
#  '100': 1351,
#  'fear': 80764,
#  'mongering': 120078,
#  'rhetoric': 147169,
#  'jesus': 104189,
#  'notch': 125956,
#  'how': 95841,
#  'wikileaks': 183593,
#  'undeniable': 174915,
#  'proof': 139279,
#  'entire': 76507,
#  'cabinet': 50934,
#  'assembled': 40162,
#  'citigroup': 55311,
#  'executives': 78439,
#  'even': 77870,
#  '2008': 5764,
#  'safe': 150042,
#  'space': 158552,
#  'ffs': 81433,
#  'topic': 169723,
#  'statement': 160362,
#  'explicitly': 78796,
#  'submissions': 162109,
#  'focus': 83091,
#  'following': 83197,
#  'things': 167931,
#  'significance': 155421,
#  'opinions': 128960,
#  'concerning': 58183,
#  'governments': 89082,
#  'courts': 60716,
#  'services': 153354,
#  'policy': 136030,
#  'making': 114349,
#  'private': 138659,
#  'actions': 33806,
#  'stories': 161241,
#  'such': 162379,
#  'demonstrations': 66827,
#  'lobbying': 112036,
#  'candidacies': 51580,
#  'funding': 85295,
#  'groups': 90045,
#  'donors': 71227,
#  'include': 99510,
#  'non': 125340,
#  'figures': 81672,
#  'ex': 78156,
#  'barack': 42900,
#  'painted': 131221,
#  'picture': 134512,
#  'relatives': 145022,
#  'associates': 40297,
#  'diane': 68188,
#  'feinstein': 81043,
#  'father': 80392,
#  'predator': 137648,
#  'attempts': 40711,
#  'murder': 121612,
#  'arnold': 39328,
#  'schwarzenegger': 151686,
#  'international': 101492,
#  'unless': 175997,
#  'discussion': 69266,
#  'focuses': 83093,
#  'implications': 98963,
#  'tension': 165872,
#  'between': 45107,
#  'greece': 89611,
#  'italy': 102821,
#  'rising': 147725,
#  'cost': 60357,
#  'feta': 81312,
#  'cheese': 54102,
#  'media': 116640,
#  'explicit': 78794,
#  'connotations': 58776,
#  'cnn': 56500,
#  'fires': 82064,
#  'wolf': 184480,
#  'blitzer': 46592,
#  'simple': 155611,
#  'straight': 161347,
#  'lie': 110946,
#  'believing': 44323,
#  'lies': 110984,
#  'era': 76963,
#  'executive': 78427,
#  'order': 129276,
#  'behind': 44173,
#  'never': 124113,
#  'day': 64651,
#  'existed': 78547,
#  'account': 33487,
#  'massive': 115564,
#  'growth': 90090,
#  'industry': 100028,
#  'came': 51361,
#  'under': 174921,
#  'during': 72900,
#  'tenure': 165894,
#  'correctness': 60169,
#  'invented': 101898,
#  'phantom': 134015,
#  'enemy': 76100,
#  'let': 110319,
#  'pretend': 138301,
#  'triggering': 170989,
#  'incidents': 99468,
#  'haven': 92523,
#  'happening': 91995,
#  'john': 104747,
#  'stuart': 161753,
#  'mill': 118357,
#  'talking': 164677,
#  'back': 42083,
#  '19th': 5167,
#  'century': 53264,
#  'called': 51261,
#  'pakistan': 131248,
#  'complimented': 57958,
#  'literally': 111621,
#  'every': 77938,
#  'sentence': 153105,
#  'comes': 57394,
#  'headline': 92787,
#  'joke': 104863,
#  'worse': 184946,
#  'the_donald': 166656,
#  'memes': 117134,
#  'conspiracy': 59060,
#  'theories': 167538,
#  'pure': 140444,
#  '24': 8263,
#  'tic': 168586,
#  'tacs': 164455,
#  'skittles': 156188,
#  'recounting': 143788,
#  'michigan': 117942,
#  'pointless': 135893,
#  'yah': 186366,
#  'actually': 33872,
#  'outsourcing': 130125,
#  'jobs': 104668,
#  'saving': 150967,
#  '1000': 1352,
#  'sending': 152996,
#  '1100': 1896,
#  'country': 60623,
#  'annoying': 37632,
#  'reading': 143045,
#  'since': 155690,
#  'negative': 123647,
#  'might': 118159,
#  'identified': 97556,
#  'sjws': 155980,
#  'internet': 101515,
#  'full': 85181,
#  'bullshit': 49706,
#  'youtube': 187267,
#  'sjw': 155974,
#  'enjoy': 76265,
#  'clown': 56301,
#  'fiesta': 81612,
#  'shit': 154412,
#  'working': 184821,
#  'cared': 52016,
#  'issues': 102742,
#  'happens': 92000,
#  'awkwardly': 41468,
#  'hold': 94955,
#  'views': 179180,
#  'social': 157601,
#  'guns': 90632,
#  'cares': 52052,
#  'appeal': 38458,
#  'voters': 180009,
#  'hint': 94410,
#  'learn': 109684,
#  'love': 112799,
#  'revolvers': 147014,
#  'breach': 48411,
#  'loading': 111994,
#  'rifles': 147424,
#  'shotguns': 154874,
#  'walmart': 180863,
#  'situation': 155904,
#  'locates': 112095,
#  'town': 170064,
#  'infrastructure': 100373,
#  'build': 49566,
#  'roads': 147937,
#  'sure': 163211,
#  'store': 161228,
#  'connected': 58729,
#  'water': 181356,
#  'sewer': 153477,
#  'electricity': 74991,
#  'sales': 150205,
#  'tax': 165119,
#  'revenue': 146885,
#  'which': 182793,
#  'enough': 76328,
#  'bonds': 47382,
#  'took': 169629,
#  'http': 96164,
#  'strongtowns': 161697,
#  'org': 129342,
#  'ponzi': 136551,
#  'scheme': 151434,
#  'missed': 119152,
#  'second': 152449,
#  'welfare': 182081,
#  'taxpayer': 165171,
#  'put': 140632,
#  'taxpayers': 165172,
#  'everyone': 77968,
#  'paying': 132447,
#  'own': 130749,
#  'dissonance': 69857,
#  'shown': 154982,
#  'theoretical': 167534,
#  'scenario': 151353,
#  'white': 182927,
#  'pride': 138454,
#  'asshole': 40222,
#  'okay': 128128,
#  'adopted': 34285,
#  'fail': 79726,
#  'substantial': 162238,
#  'difference': 68476,
#  'two': 173585,
#  'stupid': 161882,
#  'broken': 49021,
#  'family': 80020,
#  'low': 112849,
#  'voter': 179977,
#  'drug': 72275,
#  'agency': 34925,
#  'statistically': 160441,
#  'facts': 79660,
#  'feelings': 80998,
#  'whyyouareverywrong': 183402,
#  'apropos': 38728,
#  'laying': 109442,
#  'smackdown': 156819,
#  'damean1': 64107,
#  'daughter': 64534,
#  'mother': 120749,
#  'jones': 104910,
#  'writer': 185263,
#  'liberal': 110687,
#  'rag': 142134,
#  'accuses': 33551,
#  'news': 124281,
#  'stretch': 161570,
#  'david': 64573,
#  'corn': 60016,
#  'pussy': 140594,
#  'having': 92539,
#  'access': 33385,
#  'cut': 62687,
#  'off': 127779,
#  'gets': 87246,
#  '17': 4214,
#  'reporter': 145736,
#  'asked': 39966,
#  'employee': 75769,
#  'bill': 45609,
#  'countless': 60615,
#  'accused': 33547,
#  'sexual': 153524,
#  'impropriety': 99112,
#  'retort': 146703,
#  'girl': 87710,
#  'dad': 63841,
#  'probably': 138770,
#  'told': 169414,
#  'story': 161284,
#  'waiting': 180728,
#  'writes': 185269,
#  '15': 3538,
#  'total': 169891,
#  'agricultural': 35096,
#  'production': 138922,
#  'currently': 62570,
#  'shipped': 154379,
#  'rural': 149250,
#  'areas': 39048,
#  'farmers': 80215,
#  'voted': 179956,
#  'maga': 113951,
#  'cop': 59850,
#  'scientific': 151736,
#  'evidence': 78023,
#  'precursor': 137638,
#  'using': 177514,
#  'medicine': 116727,
#  'bigly': 45487,
#  'dumb': 72680,
#  'nah': 122575,
#  'ha': 91046,
#  'goodman': 88662,
#  'getting': 87261,
#  'upvoted': 177071,
#  'unironically': 175773,
#  'unqualified': 176300,
#  'investigation': 101951,
#  'treason': 170707,
#  'libertarianism': 110774,
#  'johnson': 104813,
#  'option': 129128,
#  'jill': 104408,
#  'stein': 160633,
#  'respect': 146366,
#  'candidates': 51590,
#  'deserve': 67483,
#  'presidency': 138077,
#  'else': 75300,
#  'withdrawn': 184191,
#  'left': 109852,
#  'ideal': 97512,
#  'third': 167991,
#  'world': 184860,
#  'counties': 60609,
#  'easy': 73626,
#  'fix': 82260,
#  'beyond': 45165,
#  'development': 67892,
#  'reminder': 145290,
#  'civil': 55381,
#  'rulesandregs': 149111,
#  ...}

# %% [markdown]
# ## Reference
#
# Machine Learning with Python Cookbook
# by Chris Albon
# Released March 2018
# Publisher(s): O'Reilly Media, Inc.
# ISBN: 9781491989388
